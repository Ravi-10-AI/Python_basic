# %% [markdown]
# <a href="https://colab.research.google.com/github/Ravi-10-AI/Python_basic/blob/main/Exp3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=int(input("Enter the number:"))
for i in range(1):
  if a%2==0:
    print(a,"Even number")
  else:
    print(a,"Odd number")
# Out:
# Enter the number:24
# 24 Even number

# %%
for i in range(2,11):
  print("1/",i,"=",1/i)
# Out:
# 1/ 2 = 0.5
# 1/ 3 = 0.3333333333333333
# 1/ 4 = 0.25
# 1/ 5 = 0.2
# 1/ 6 = 0.16666666666666666
# 1/ 7 = 0.14285714285714285
# 1/ 8 = 0.125
# 1/ 9 = 0.1111111111111111
# 1/ 10 = 0.1

# %%
my_list = [10, 20, 30, 40]
my_tuple = (10, 20, 30, 40)
print("List elements:")
for item in my_list:
    print(item)
print("Tuple elements:")
for item in my_tuple:
    print(item)
# Out:
# List elements:
# 10
# 20
# 30
# 40
# Tuple elements:
# 10
# 20
# 30
# 40
