# %% [markdown]
# <a href="https://colab.research.google.com/github/Ravi-10-AI/Python_basic/blob/main/Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = float(input("Enter a number: "))

if num > 0:
    print("The number is positive.")
elif num < 0:
    print("The number is negative.")
else:
    print("The number is zero.")
# Out:
# Enter a number: 10
# The number is positive.

# %%
num = int(input("Enter a number: "))

if num % 5 == 0 and num % 11 == 0:
    print("The number is divisible by both 5 and 11.")
elif num % 5 == 0:
    print("The number is divisible by 5.")
elif num % 11 == 0:
    print("The number is divisible by 11.")
else:
    print("The number is not divisible by 5 or 11.")
# Out:
# Enter a number: 45
# The number is divisible by 5.

# %%
n = int(input("Enter the range limit: "))

for i in range(1, n + 1):
    print(f"Square of {i} is {i * i}")
# Out:
# Enter the range limit: 6
# Square of 1 is 1
# Square of 2 is 4
# Square of 3 is 9
# Square of 4 is 16
# Square of 5 is 25
# Square of 6 is 36
