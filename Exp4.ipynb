# %% [markdown]
# <a href="https://colab.research.google.com/github/Ravi-10-AI/Python_basic/blob/main/Exp4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
my_list = [10, 20, 30, 40]
my_tuple = (10, 20, 30, 40)
print("List elements:")
for item in my_list:
    print(item)
print("Tuple elements:")
for item in my_tuple:
    print(item)
# Out:
# List elements:
# 10
# 20
# 30
# 40
# Tuple elements:
# 10
# 20
# 30
# 40

# %%
sequence = [1, 2, 3, 4, 5]
for i in sequence:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
num = int(input("Enter a number: "))
while num >= 0:
    print(num)
    num -= 1
# Out:
# Enter a number: 6
# 6
# 5
# 4
# 3
# 2
# 1
# 0
